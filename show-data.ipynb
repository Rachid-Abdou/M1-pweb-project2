# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
path = "./data/data.xlsx"
#data = pd.read_excel(path , sheet_name=None)

# Read all sheets in your File
df1 = pd.read_excel(path, sheet_name=None)
    
# Prints all the sheets name in an ordered dictionary
print(df1.keys())

df = pd.concat([pd.read_excel(path, sheet_name = sheet) for sheet in df1.keys()], ignore_index = True)
# Out:
# dict_keys(['2019', '2020', '2021'])

# %%
df.head
# Out:
# <bound method NDFrame.head of       ANNEE   ID       NOM      PRENOM SEXE    SPECIALITE    MOYENNE
# 0      2019    1      Nash  Bernadette    F  SPECIALITE_1  17.542495
# 1      2019    2     Grant       Karen    F  SPECIALITE_1  17.292186
# 2      2019    3     Grant       Karen    F  SPECIALITE_1  16.579241
# 3      2019    4     Grant       Karen    F  SPECIALITE_1  16.412107
# 4      2019    5      Kerr      Rachel    F  SPECIALITE_1  16.374424
# ...     ...  ...       ...         ...  ...           ...        ...
# 1331   2021  469   Lambert     Leonard    H  SPECIALITE_7  13.939604
# 1332   2021  470   Langdon        Liam    H  SPECIALITE_7  13.412781
# 1333   2021  471  Lawrence       Lucas    H  SPECIALITE_7  15.549682
# 1334   2021  472       Lee        Luke    H  SPECIALITE_7  15.570551
# 1335   2021  473     Lewis        Matt    H  SPECIALITE_7  13.282605
#
# [1336 rows x 7 columns]>

# %%
list(df['ANNEE'].value_counts())
# Out:
# [473, 442, 421]

# %%
list(df.groupby('ANNEE')['MOYENNE'].mean())
# Out:
# [11.547877041635527, 11.247504096582217, 12.396166985129119]

# %%
df2 = df[['ANNEE', 'SEXE', 'SPECIALITE', 'MOYENNE']]
df2.head()
# Out:
#    ANNEE SEXE    SPECIALITE    MOYENNE
# 0   2019    F  SPECIALITE_1  17.542495
# 1   2019    F  SPECIALITE_1  17.292186
# 2   2019    F  SPECIALITE_1  16.579241
# 3   2019    F  SPECIALITE_1  16.412107
# 4   2019    F  SPECIALITE_1  16.374424

# %%
print(df2['ANNEE'].value_counts())
print(df2['SEXE'].value_counts())
print(df2[ 'SPECIALITE'].value_counts())
# Out:
# 2021    473
# 2020    442
# 2019    421
# Name: ANNEE, dtype: int64
# H    673
# F    663
# Name: SEXE, dtype: int64
# SPECIALITE_6    257
# SPECIALITE_7    222
# SPECIALITE_4    213
# SPECIALITE_5    208
# SPECIALITE_3    176
# SPECIALITE_2    137
# SPECIALITE_1    123
# Name: SPECIALITE, dtype: int64

# %%
df2[df2['SEXE'] == 'H']
# Out:
#       ANNEE SEXE    SPECIALITE    MOYENNE
# 6      2019    H  SPECIALITE_1  16.119148
# 7      2019    H  SPECIALITE_1  15.396427
# 8      2019    H  SPECIALITE_1  15.096163
# 10     2019    H  SPECIALITE_1  14.567848
# 11     2019    H  SPECIALITE_1  14.302411
# ...     ...  ...           ...        ...
# 1331   2021    H  SPECIALITE_7  13.939604
# 1332   2021    H  SPECIALITE_7  13.412781
# 1333   2021    H  SPECIALITE_7  15.549682
# 1334   2021    H  SPECIALITE_7  15.570551
# 1335   2021    H  SPECIALITE_7  13.282605
#
# [673 rows x 4 columns]

# %%
# Filter data for male and female
df_m = df2[df2['SEXE'] == 'H'][['SPECIALITE','MOYENNE']]
df_f = df2[df2['SEXE'] == 'F'][['SPECIALITE','MOYENNE']]

# %%
df_m
# Out:
#         SPECIALITE    MOYENNE
# 6     SPECIALITE_1  16.119148
# 7     SPECIALITE_1  15.396427
# 8     SPECIALITE_1  15.096163
# 10    SPECIALITE_1  14.567848
# 11    SPECIALITE_1  14.302411
# ...            ...        ...
# 1331  SPECIALITE_7  13.939604
# 1332  SPECIALITE_7  13.412781
# 1333  SPECIALITE_7  15.549682
# 1334  SPECIALITE_7  15.570551
# 1335  SPECIALITE_7  13.282605
#
# [673 rows x 2 columns]

# %%
# Filter data for male and female
df_m = df2[df2['SEXE'] == 'H'][['SPECIALITE','MOYENNE']]
df_f = df2[df2['SEXE'] == 'F'][['SPECIALITE','MOYENNE']]

# Filter data for male and female
df_male = df2[df2['SEXE'] == 'H'].groupby('SPECIALITE')['MOYENNE'].mean()
df_female = df2[df2['SEXE'] == 'F'].groupby('SPECIALITE')['MOYENNE'].mean()


xm = list(df_male.keys())
ym = list(df_male)

xf = list(df_female.keys())
yf = list(df_female)

# %%
print(type(df_male))
print(df_female)
# Out:
# <class 'pandas.core.series.Series'>
# SPECIALITE
# SPECIALITE_1    11.818839
# SPECIALITE_2    11.836528
# SPECIALITE_3    11.920924
# SPECIALITE_4    11.635809
# SPECIALITE_5    12.261027
# SPECIALITE_6    11.401815
# SPECIALITE_7    11.827873
# Name: MOYENNE, dtype: float64

# %%
xm = list(df_male.keys())
ym = list(df_male)

xf = list(df_female.keys())
yf = list(df_female)

# %%
print(xm)
print(ym)
print(xf)
print(yf)
# Out:
# ['SPECIALITE_1', 'SPECIALITE_2', 'SPECIALITE_3', 'SPECIALITE_4', 'SPECIALITE_5', 'SPECIALITE_6', 'SPECIALITE_7']
# [11.598322345066839, 11.65296961342309, 12.088398011568486, 11.906854221273385, 11.597857273403994, 11.49842671035527, 11.6391526967359]
# ['SPECIALITE_1', 'SPECIALITE_2', 'SPECIALITE_3', 'SPECIALITE_4', 'SPECIALITE_5', 'SPECIALITE_6', 'SPECIALITE_7']
# [11.818839034124826, 11.836527501473997, 11.920923666866399, 11.635808692353217, 12.261027177815649, 11.401814845029326, 11.827873164400861]

# %%
test = df_male.groupby('SPECIALITE').mean()
test.head()
# Out:
# /var/folders/jx/39f5v9_1541c0j_2vb0z_b_w0000gn/T/ipykernel_1265/2901855377.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#                     ANNEE    MOYENNE
# SPECIALITE
# SPECIALITE_1  2019.928571  11.598322
# SPECIALITE_2  2020.077922  11.652970
# SPECIALITE_3  2020.068966  12.088398
# SPECIALITE_4  2019.936364  11.906854
# SPECIALITE_5  2020.018868  11.597857

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df2 is your DataFrame

# Filter data for male and female
df_male = df2[df2['SEXE'] == 'H']
df_female = df2[df2['SEXE'] == 'F']

# Create a line plot for male
plt.figure(figsize=(12, 6))
sns.lineplot(x='SPECIALITE', y='MOYENNE', data=df_male, ci=None, label='Male', marker='o')

# Create a line plot for female
sns.lineplot(x='SPECIALITE', y='MOYENNE', data=df_female, ci=None, label='Female', marker='o')

plt.title('Mean MOYENNE across SPECIALITE for Male and Female')
plt.xlabel('SPECIALITE')
plt.ylabel('Mean MOYENNE')
plt.legend()
plt.show()
# Out:
# /var/folders/jx/39f5v9_1541c0j_2vb0z_b_w0000gn/T/ipykernel_1265/1819585957.py:12: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#
# /var/folders/jx/39f5v9_1541c0j_2vb0z_b_w0000gn/T/ipykernel_1265/1819585957.py:15: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %%
df2['ANNEE'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Distribution of ANNEE')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
df2['SEXE'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightcoral'])
plt.title('Distribution of SEXE')
plt.show()

# %%
print(list(df2['SPECIALITE'].unique()))
print(list(df2['SPECIALITE'].value_counts()))
# Out:
# ['SPECIALITE_1', 'SPECIALITE_2', 'SPECIALITE_3', 'SPECIALITE_4', 'SPECIALITE_5', 'SPECIALITE_6', 'SPECIALITE_7']
# [257, 222, 213, 208, 176, 137, 123]

# %%
df2['SPECIALITE'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Distribution of SPECIALITE')
plt.xlabel('Specialization')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(df2['MOYENNE'], bins=20, color='orange', edgecolor='black')
plt.title('Distribution of MOYENNE')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
avg_scores = df.groupby('ANNEE')['MOYENNE'].mean()
avg_scores.plot(kind='bar', color='skyblue')
plt.title('Average Scores')
plt.xlabel('Specialty')
plt.ylabel('Average Score')
plt.show()

# %%
avg_scores = list(df.groupby('ANNEE')['MOYENNE'].mean())
list(avg_scores)
# Out:
# [11.547877041635527, 11.247504096582217, 12.396166985129119]

# %%
df.isna().sum()
# Out:
# ANNEE         0
# ID            0
# NOM           0
# PRENOM        0
# SEXE          0
# SPECIALITE    0
# MOYENNE       0
# dtype: int64

# %%
# Plot 1: Bar plot for average scores
avg_scores = df.groupby('SPECIALITE')['MOYENNE'].mean()
avg_scores.plot(kind='bar', color='skyblue')
plt.title('Average Scores')
plt.xlabel('Specialty')
plt.ylabel('Average Score')
plt.show()

# %%
# Box plot for score distribution by 'ANNEE'
plt.figure(figsize=(10, 6))
df.boxplot(column='MOYENNE', by='ANNEE', showfliers=False)
plt.title('Score Distribution by Year (ANNEE)')
plt.xlabel('Year (ANNEE)')
plt.ylabel('Score')
plt.suptitle('')  # Remove the default title added by pandas
plt.show()

# %%
# Box plot for score distribution by 'ANNEE' and 'SPECIALITE'
plt.figure(figsize=(12, 8))
df.boxplot(column='MOYENNE', by=['ANNEE', 'SPECIALITE'], showfliers=False)
plt.title('Score Distribution by Year (ANNEE) and Specialty (SPECIALITE)')
plt.xlabel('Year (ANNEE) - Specialty (SPECIALITE)')
plt.ylabel('Score')
plt.suptitle('')  # Remove the default title added by pandas
plt.xticks(rotation=90, ha='center')  # Rotate x-axis labels for better readability
plt.show()

# %%
# Plot 4: Histogram for distribution of scores
plt.hist(df['MOYENNE'], bins=20, color='orange', edgecolor='black')
plt.title('Score Distribution')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot 6: Pie chart for gender distribution
gender_distribution = df['SEXE'].value_counts()
gender_distribution.plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightcoral'])
plt.title('Gender Distribution')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Plot 1: Violin plot for score distribution by gender
plt.figure(figsize=(10, 6))
sns.violinplot(x='SEXE', y='MOYENNE', data=df, palette='pastel')
plt.title('Score Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Score')
plt.show()

# %%
# Plot 2: Pair plot for relationship exploration
sns.pairplot(df[['MOYENNE', 'SEXE', 'SPECIALITE']], hue='SPECIALITE', palette='Set2')
plt.suptitle('Pair Plot for Scores, Gender, and Specialty', y=1.02)
plt.show()

# Plot 3: Swarm plot for distribution of scores by gender
plt.figure(figsize=(10, 6))
sns.swarmplot(x='SEXE', y='MOYENNE', data=df, palette='dark', alpha=0.7)
plt.title('Score Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Score')
plt.show()
# Out:
# /var/folders/jx/39f5v9_1541c0j_2vb0z_b_w0000gn/T/ipykernel_29969/1146420787.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='SEXE', y='MOYENNE', data=df, palette='dark', alpha=0.7)
